# %%
import pandas as pd

df = pd.read_csv('ar41_for_ulb.csv', sep=';')
df.isna().sum()

# %%
df
# Out:
#           Unnamed: 0  mapped_veh_id       timestamps_UTC        lat       lon  \
# 0                  0          181.0  2023-08-01 03:44:12  50.769818  3.872114
# 1                  1          143.0  2023-08-01 06:36:29  51.039993  3.693429
# 2                  2          183.0  2023-08-24 06:53:54  50.742203  3.602035
# 3                  3          177.0  2023-08-01 13:53:38  50.930914  5.327132
# 4                  4          143.0  2023-08-24 07:02:30  51.180773  3.575259
# ...              ...            ...                  ...        ...       ...
# 17679268    17679268          180.0  2023-05-28 19:28:59  50.919864  3.791125
# 17679269    17679269          180.0  2023-05-28 19:54:41  51.035243  3.710695
# 17679270    17679270          122.0  2023-05-28 20:23:20  51.015686  3.775316
# 17679271    17679271          177.0  2023-05-28 20:46:00  51.189586  5.109380
# 17679272    17679272          110.0  2023-05-28 21:05:24  51.041178  3.683947
#
# ...

# %%
df['timestamps_UTC'] = pd.to_datetime(df['timestamps_UTC'])

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# mapped_veh_id             0
# timestamps_UTC            0
# lat                       0
# lon                       0
# RS_E_InAirTemp_PC1        0
# RS_E_InAirTemp_PC2    12726
# RS_E_OilPress_PC1         0
# RS_E_OilPress_PC2     12726
# RS_E_RPM_PC1              0
# RS_E_RPM_PC2          12726
# RS_E_WatTemp_PC1          0
# RS_E_WatTemp_PC2      12726
# RS_T_OilTemp_PC1          0
# RS_T_OilTemp_PC2      12726
# dtype: int64
