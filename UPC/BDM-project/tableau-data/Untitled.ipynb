# %%
import pandas as pd
import numpy as np

# %%
def insert_age_column(file_path, output_file_path):
    data = pd.read_csv(file_path)
    n = len(data)
    age_brackets = [(18, 25), (26, 35), (36, 45)]
    probabilities = [0.523, 0.314, 0.163]
    np.random.seed(42)
    ages = np.random.choice(
        [np.random.randint(low, high + 1) for low, high in age_brackets],
        size=n,
        p=probabilities
    )
    
    age_column_index = data.columns.get_loc("name") + 1
    data.insert(loc=age_column_index, column='age', value=ages)
    data.to_csv(output_file_path, index=False)
    
file_path = 'user-data.csv'  
output_file_path = 'user-data.csv'  
insert_age_column(file_path, output_file_path)

# %%
def add_event_titles_to_csv(csv_path):
    event_titles = [
        "Champions of Tomorrow: Youth Sports Conference", "Marathon Mastery: Techniques and Tips",
        "High Altitude Triumph: Elite Mountaineering Meetup", "Soccer Skills Workshop: Play Like a Pro",
        "The Future of Sports: Trends and Predictions Panel", "Water Sports Expo: Surf, Swim, and Sail",
        "Athletic Nutrition Forum: Eat to Compete", "Cycling for Success: Races and Rides Networking Event",
        "Winter Sports Wonderland: Skiing and Snowboarding Techniques", "Olympic Dreams: Training with the Best",
        "Tech Trends 2025: What's Next in Innovation", "Cybersecurity Summit: Defending Digital Frontiers",
        "AI and You: Embracing the Future of Technology", "Smart Home Hackathon: Building the Future of Living",
        "Code and Coffee: Morning Programming Meetup", "Virtual Reality: The New Frontier of Gaming and Work",
        "Women in Tech: Empowering Innovation", "The IoT Revolution: Creating Connected Experiences",
        "Mobile Apps Marathon: From Idea to Launch", "Cloud Computing Conference: Navigating the Sky",
        "Modern Art Movements: A Visual Journey", "Sculpture Now: Forms of the 21st Century",
        "Street Art Spectacular: Urban Creativity Unleashed", "The Art of Color: Theory and Practice Workshop",
        "Gallery Gala: Emerging Artists Spotlight", "Digital Art and Design: Trends and Tools",
        "Art Collectors' Forum: Investing in Contemporary Art", "Portrait Painting Masterclass: Capturing the Human Spirit",
        "Mixed Media Explorations: Art in New Dimensions", "Public Art Projects: Making Spaces Speak",
        "Fiction Frenzy: Celebrating New Authors", "Memoir Writing Workshop: Tell Your Story",
        "Children's Literature Conference: Inspiring Young Minds", "Poetry and Prose: A Literary Evening",
        "Mystery and Thriller: Crafting Suspenseful Plots", "Science Fiction Symposium: Futures Imagined",
        "Book Marketing 101: Strategies for Authors", "Historical Novels Hub: A Blast from the Past",
        "Young Adult Fiction: Trends and Triumphs", "Non-Fiction Now: Engaging with Reality",
        "Big Data and Beyond: Exploring the Universe of Data", "Machine Learning Mastery: From Theory to Practice",
        "Predictive Analytics in Action: Tools and Techniques", "Deep Learning Developments: AI's Cutting Edge",
        "Data Science for Healthcare: Improving Lives with Data", "Sports Analytics: Data-Driven Athletic Enhancements",
        "Python for Data Science: Code and Concepts", "Financial Forecasting: Data Science in Economics",
        "Data Visualization Workshop: Seeing is Believing", "NLP with Python: Textual Data Decoded",
        "Data-Driven Decision Making: A Strategic Approach", "AI in Retail: Enhancing Customer Experience with Data",
        "Real-time Data Processing: Speed and Scale", "Data Science for Social Good: Making a Difference",
        "Data Warehousing Solutions: Storage and Retrieval", "Blockchain Data Analytics: Exploring New Frontiers",
        "Internet of Things (IoT) and Data: The Connected World", "Data Science in Education: Learning Empowered",
        "Fraud Detection using Data Science: Safeguarding Assets", "Geospatial Data Applications: Mapping the Future",
        "Data Ethics: Responsibility in the Age of Big Data", "Cloud-Based Data Science: Accessible and Powerful",
        "Customer Analytics: Understanding Consumer Behavior", "Time Series Analysis: Forecasting the Future",
        "Data Science for Beginners: An Introductory Workshop", "Advanced Analytics Techniques: Insights into Data",
        "Machine Learning for Web Development: Integrating AI", "Data Governance: Protecting and Managing Information",
        "Text Analytics: Unlocking the Value in Words", "Data Integration Strategies: A Comprehensive Approach",
        "Global Cuisines: Cooking Techniques from Around the World", "Farm to Table: Sustainable Cooking Workshop",
        "Baking Basics: Pastries, Pies, and More", "Vegan Delights: Cooking for Health and Pleasure",
        "Seafood Sensations: Cooking with Fresh Catch", "Spice Mastery: Flavors from the East",
        "Italian Cooking Class: Pasta and Sauces", "French Culinary Arts: Techniques and Traditions",
        "Cooking with Wine: Pairing and Preparing", "Chocolate Creations: From Bean to Bar",
        "Landscape Painting Retreat: Capturing Nature", "Abstract Art Workshop: Expressing Inner Thoughts",
        "Watercolor Techniques: Fluidity and Form", "Acrylics A-Z: A Complete Guide to Modern Painting",
        "Portrait Painting Intensive: Faces and Features", "Paint Like the Masters: Classical Techniques Today",
        "Street Art and Mural Painting: Bold and Bright", "Eco-Friendly Painting: Sustainable Practices",
        "Mixed Media Painting: Layering and Texturing Techniques", "Still Life Painting: Detail and Depth",
        "Trail Blazers: Hiking Adventures Await", "Mountain Mastery: Hiking High Altitudes",
        "Forest Pathways: Hiking and Conservation", "Desert Trekking: Surviving and Thriving",
        "Island Hiking: Seascapes and Landscapes", "Winter Wilderness: Snowshoeing and Safety",
        "Hiking Health: Fitness and Wellbeing on the Trails", "Family Friendly Hikes: Fun for All Ages",
        "Night Hiking: The Stars Above", "Birdwatching Hikes: Nature's Flyers",
        "Photography on the Trail: Capturing the Great Outdoors", "Historic Trails: Hiking Through History",
        "Coastal Hikes: Sea Breezes and Cliff Views", "Ultra Hiking Challenges: Are You Ready?",
        "Ecotourism Hikes: Sustainable Exploration", "Solo Hiking Safety: Tips and Tricks",
        "Hiking Gear and Gadgets: Packing Smart", "Mindful Hiking: Meditation and Movement",
        "Mind Matters: Exploring Psychological Theories", "Child Psychology and Development: Shaping the Future",
        "Cognitive Behavioral Therapy: Techniques and Outcomes", "The Psychology of Happiness: Pursuing Wellbeing",
        "Mental Health in Modern Times: Challenges and Solutions", "Neuroscience and Psychology: The Brain Connection",
        "Social Psychology: Understanding Group Dynamics", "Forensic Psychology: Minds of Crime",
        "Sports Psychology: Peak Performance", "Clinical Psychology Interventions: From Theory to Practice",
        "Behavioral Economics: The Psychology of Spending", "Environmental Psychology: Space, Place, and Behavior",
        "Psychology of Aging: Healthy Mind, Healthy Body", "Educational Psychology: Learning and Teaching",
        "Therapeutic Practices: Different Approaches to Therapy", "Organizational Psychology: Optimizing Work Environments",
        "Psychological Assessment: Tools and Techniques", "Brewing Basics: Introduction to Coffee Making",
        "The Art of Espresso: Techniques and Tastes", "Coffee Around the World: A Tasting Tour",
        "Cold Brew Creations: Innovations in Iced Coffee", "Barista Skills Workshop: Craft the Perfect Cup",
        "Coffee Roasting at Home: Techniques and Tips", "Sustainable Coffee Practices: From Farm to Cup",
        "Latte Art Throwdown: Compete and Create", "Coffee and Health: Benefits and Considerations",
        "The Business of Coffee: Opening Your Café", "Coffee Tasting Mastery: Developing Your Palate",
        "Specialty Coffees: Exploring Unique Blends", "Coffee and Chocolate: Pairing Perfection",
        "Advanced Coffee Brewing: Techniques and Tools", "Coffee in Literature and Art: Cultural Reflections",
        "Historical Perspectives on Coffee: A Global Journey", "Coffee Shop Design: Creating Welcoming Spaces",
        "Coffee Festivals: Celebrating the Bean", "Coffee Trade and Economics: A Global View",
        "DIY Coffee Crafts: Creative Uses for Coffee", "Investment Strategies for Beginners: Getting Started",
        "Real Estate Investing: Building Wealth", "Stock Market 101: Understanding the Basics",
        "Venture Capital: Investing in Startups", "Cryptocurrency Investment Insights: Beyond Bitcoin",
        "Portfolio Management: Balancing Risk and Reward", "Retirement Planning: Secure Your Future",
        "Tax Efficient Investing: Smart Savings Strategies", "Angel Investing: Supporting Early-Stage Enterprises",
        "Commodities Trading: Gold, Oil, and More", "ETFs and Mutual Funds: Diversified Investing",
        "Sustainable and Ethical Investing: Good Returns", "Financial Planning for Millennials: A Modern Approach",
        "Forex Trading: Currency Market Dynamics", "Value Investing: Long-Term Wealth Growth",
        "Investment Banking Explained: An Industry Overview", "Tech Investments: The Future of Finance",
        "Personal Finance and Wealth Management", "Investing in Art: Aesthetic and Financial Returns",
        "Emerging Markets: Opportunities and Challenges", "Behavioral Finance: Understanding Investor Psychology",
        "Income Investing: Strategies for Cash Flow", "Private Equity: Inside High-Stakes Investments",
        "Bond Investing: Safety and Stability", "Market Analysis Techniques: Predicting Financial Trends",
        "Bitcoin Basics: Understanding Cryptocurrencies", "Bitcoin Mining: How it Works",
        "Investing in Bitcoin: Opportunities and Risks", "Bitcoin and Blockchain: Technology for a New Economy",
        "Bitcoin Regulation: Legal Landscapes", "Bitcoin Wallets: Keeping Your Crypto Safe",
        "Bitcoin Markets: Trading and Trends", "Bitcoin in Developing Countries: Opportunities for Growth",
        "The Future of Bitcoin: Predictions and Pathways", "Bitcoin and Beyond: The Next Generation of Cryptocurrencies",
        "Mastering Mindfulness: Enhancing Personal Wellbeing", "Productivity Power: Tools and Techniques for Efficiency",
        "Leadership Skills for the 21st Century", "Emotional Intelligence: Boost Your EQ",
        "Time Management Mastery: Own Your Time", "Creative Thinking: Unlock Your Innovative Potential",
        "Building Resilience: Thrive in Tough Times", "Personal Branding: Crafting Your Online Presence",
        "Goal Setting Workshop: Achieving Your Dreams", "Conflict Resolution: Strategies for Harmony",
        "Startup Success: Launching Your Business Idea", "Entrepreneurial Mindset: Cultivating Innovation",
        "Funding Your Venture: Angel Investors and VCs", "Building a Brand: Marketing Strategies for Startups",
        "Growth Hacking: Accelerating Startup Success", "Networking for Entrepreneurs: Making Meaningful Connections",
        "Lean Startup Methodology: Build, Measure, Learn", "E-commerce Essentials: Selling Online",
        "Tech Startups: Navigating the High-Tech World", "Social Entrepreneurship: Business for Social Good"
    ]
    
    event_types = ["Sports"] * 10 + ["IT"] * 10 + ["Art"] * 10 + ["Books"] * 10 + ["Data Science"] * 30 + ["Cooking"] * 10 + \
                  ["Painting"] * 10 + ["Hiking"] * 18 + ["Psychology"] * 17 + ["Coffee"] * 20 + ["Investments"] * 25 + \
                  ["Bitcoin"] * 10 + ["Self-development"] * 10 + ["Entrepreneurship"] * 10

    new_data_df = pd.DataFrame({
        "Event Title": event_titles,
        "Event Type": event_types
    })

    try:
        existing_df = pd.read_csv(csv_path)
    except FileNotFoundError:
        print(f"No existing file found at {csv_path}. A new file will be created.")
        existing_df = pd.DataFrame()

    combined_df = pd.concat([existing_df, new_data_df], axis=1)

    combined_df.to_csv(csv_path, index=False)
    print(f"Data successfully updated and saved to {csv_path}")

csv_file_path = 'user-data.csv'
add_event_titles_to_csv(csv_file_path)
# Out:
# Data successfully updated and saved to user-data.csv
