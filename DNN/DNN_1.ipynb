# %%
# Import the required packages
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import scipy

# %%
# Display plots in notebook 
# %matplotlib inline
# Define plot's default figure size
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
#read the datasets
train = pd.read_csv("intro_to_ann.csv")

# %%
X, y = np.array(train.ix[:,0:2]), np.array(train.ix[:,2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9580bd8d752a> in <module>
# ----> 1 X, y = np.array(train.ix[:,0:2]), np.array(train.ix[:,2])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
#explain in this cell why the above code did not work out

# %%
X, y = np.array(train.loc[:, ['Feature1', 'Feature2']]), np.array(train.loc[:, 'Target'])

# %%
X.shape
# Out:
# (500, 2)

# %%
y.shape
# Out:
# (500,)

# %%
#Let's plot the dataset and see how it is
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.BuGn)

# %%
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.viridis)  # Using the viridis colormap
plt.colorbar()  # Optionally, add a color bar to understand the mapping
plt.show()
