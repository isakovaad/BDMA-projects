# %%
pip install apache-airflow
# Out:
# Collecting apache-airflow
#   Using cached apache_airflow-2.7.3-py3-none-any.whl (12.9 MB)
# Requirement already satisfied: apache-airflow-providers-common-sql in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.8.0)
# Requirement already satisfied: pyjwt>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.8.0)
# Requirement already satisfied: setproctitle>=1.1.8 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.3.3)
# Requirement already satisfied: tabulate>=0.7.5 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.9.0)
# Requirement already satisfied: unicodecsv>=0.14.1 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.14.1)
# Collecting configupdater>=3.1.1
#   Using cached ConfigUpdater-3.1.1-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: python-dateutil>=2.3 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.8.2)
# Collecting argcomplete>=1.10
#   Downloading argcomplete-3.1.6-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 155 kB/s eta 0:00:01
# Requirement already satisfied: connexion[flask]<3.0,>=2.10.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.14.2)
# Requirement already satisfied: markdown-it-py>=2.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (3.0.0)
# Collecting apache-airflow-providers-imap
#   Using cached apache_airflow_providers_imap-3.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: cryptography>=0.9.3 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (3.4.7)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.4.0)
# Requirement already satisfied: WTForms<3.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (3.0.1)
# Requirement already satisfied: rich>=12.4.4 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (13.6.0)
# Collecting blinker
#   Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: python-slugify>=5.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (8.0.1)
# Collecting google-re2>=1.0
#   Using cached google-re2-1.1.tar.gz (10 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (4.8.0)
# Collecting flask-appbuilder==4.3.6
#   Using cached Flask_AppBuilder-4.3.6-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: rich-argparse>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.4.0)
# Collecting apache-airflow-providers-sqlite
#   Using cached apache_airflow_providers_sqlite-3.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: attrs>=22.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (23.1.0)
# Requirement already satisfied: pydantic>=1.10.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.4.2)
# Requirement already satisfied: deprecated>=1.2.13 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.2.14)
# Collecting dill>=0.2.2
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 56 kB/s eta 0:00:01
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.3.0)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.28 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.4.50)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.0.1.post0)
# Requirement already satisfied: tenacity!=8.2.0,>=6.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (8.2.3)
# Requirement already satisfied: pygments>=2.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.16.1)
# Collecting flask-session>=0.4.0
#   Using cached flask_session-0.5.0-py3-none-any.whl (7.2 kB)
# Collecting alembic<2.0,>=1.6.3
#   Using cached alembic-1.12.1-py3-none-any.whl (226 kB)
# Requirement already satisfied: opentelemetry-api>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.20.0)
# Collecting cattrs>=22.1.0
#   Using cached cattrs-23.1.2-py3-none-any.whl (50 kB)
# Collecting cron-descriptor>=1.2.24
#   Using cached cron_descriptor-1.4.0-py3-none-any.whl
# Requirement already satisfied: markdown>=3.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (3.5.1)
# Requirement already satisfied: flask-wtf>=0.15 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.2.1)
# Requirement already satisfied: pluggy>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.3.0)
# Collecting apache-airflow-providers-http
#   Downloading apache_airflow_providers_http-4.7.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: python-nvd3>=0.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.15.0)
# Requirement already satisfied: graphviz>=0.12 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.20.1)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.23.3)
# Requirement already satisfied: markupsafe>=1.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.1.3)
# Requirement already satisfied: lockfile>=0.12.2 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.12.2)
# Collecting colorlog<5.0,>=4.0.2
#   Using cached colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (4.19.2)
# Requirement already satisfied: lazy-object-proxy in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.9.0)
# Requirement already satisfied: importlib-metadata>=1.7 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (6.8.0)
# Collecting apache-airflow-providers-ftp
#   Downloading apache_airflow_providers_ftp-3.6.1-py3-none-any.whl (18 kB)
# Collecting croniter>=0.3.17
#   Using cached croniter-2.0.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: python-daemon>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (3.0.1)
# Requirement already satisfied: importlib-resources>=5.2 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (6.1.0)
# Requirement already satisfied: psutil>=4.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (5.9.6)
# Requirement already satisfied: flask-login>=0.6.2 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.6.3)
# Requirement already satisfied: gunicorn>=20.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (21.2.0)
# Requirement already satisfied: linkify-it-py>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.0.2)
# Requirement already satisfied: opentelemetry-exporter-otlp in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (1.20.0)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (3.0.1)
# Requirement already satisfied: packaging>=14.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (23.2)
# Requirement already satisfied: asgiref in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (3.7.2)
# Requirement already satisfied: rfc3339-validator>=0.1.4 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.1.4)
# Requirement already satisfied: flask<2.3,>=2.2 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.2.5)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (0.11.2)
# Requirement already satisfied: pendulum<3.0,>=2.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.1.2)
# Requirement already satisfied: jinja2>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (3.1.2)
# Requirement already satisfied: werkzeug>=2.0 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow) (2.2.3)
# Collecting flask-caching>=1.5.0
#   Using cached Flask_Caching-2.1.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: Flask-Babel<3,>=1 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (2.0.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (2.5.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (0.4.6)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (0.2.1)
# Requirement already satisfied: apispec[yaml]<7,>=6.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (6.3.0)
# Requirement already satisfied: click<9,>=8 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (8.1.7)
# Requirement already satisfied: marshmallow-sqlalchemy<0.27.0,>=0.22.0 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (0.26.1)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (0.41.1)
# Requirement already satisfied: marshmallow<4,>=3.18.0 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (3.20.1)
# Requirement already satisfied: email-validator<2,>=1.0.5 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (1.3.1)
# Requirement already satisfied: Flask-Limiter<4,>3 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (3.5.0)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from flask-appbuilder==4.3.6->apache-airflow) (4.5.3)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.8/site-packages (from alembic<2.0,>=1.6.3->apache-airflow) (1.2.4)
# Requirement already satisfied: PyYAML>=3.10 in /opt/anaconda3/lib/python3.8/site-packages (from apispec[yaml]<7,>=6.0.0->flask-appbuilder==4.3.6->apache-airflow) (6.0.1)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/lib/python3.8/site-packages (from cattrs>=22.1.0->apache-airflow) (1.1.3)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in /opt/anaconda3/lib/python3.8/site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow) (0.5.1)
# Requirement already satisfied: requests<3,>=2.9.1 in /opt/anaconda3/lib/python3.8/site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow) (2.31.0)
# Requirement already satisfied: clickclick<21,>=1.2 in /opt/anaconda3/lib/python3.8/site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow) (20.10.2)
# Requirement already satisfied: pytz>2021.1 in /opt/anaconda3/lib/python3.8/site-packages (from croniter>=0.3.17->apache-airflow) (2023.3.post1)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.8/site-packages (from cryptography>=0.9.3->apache-airflow) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow) (2.21)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/anaconda3/lib/python3.8/site-packages (from deprecated>=1.2.13->apache-airflow) (1.15.0)
# Requirement already satisfied: idna>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.3.6->apache-airflow) (3.4)
# Requirement already satisfied: dnspython>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.3.6->apache-airflow) (2.4.2)
# Requirement already satisfied: Babel>=2.3 in /opt/anaconda3/lib/python3.8/site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.3.6->apache-airflow) (2.13.1)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in /opt/anaconda3/lib/python3.8/site-packages (from flask-caching>=1.5.0->apache-airflow) (0.9.0)
# Requirement already satisfied: limits>=2.8 in /opt/anaconda3/lib/python3.8/site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.3.6->apache-airflow) (3.6.0)
# Requirement already satisfied: ordered-set<5,>4 in /opt/anaconda3/lib/python3.8/site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.3.6->apache-airflow) (4.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=1.7->apache-airflow) (3.17.0)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=4.18.0->apache-airflow) (0.30.2)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=4.18.0->apache-airflow) (1.3.10)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=4.18.0->apache-airflow) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=4.18.0->apache-airflow) (0.10.6)
# Requirement already satisfied: uc-micro-py in /opt/anaconda3/lib/python3.8/site-packages (from linkify-it-py>=2.0.0->apache-airflow) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.1.0->apache-airflow) (0.1.2)
# Requirement already satisfied: pytzdata>=2020.1 in /opt/anaconda3/lib/python3.8/site-packages (from pendulum<3.0,>=2.0->apache-airflow) (2020.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from prison<1.0.0,>=0.2.1->flask-appbuilder==4.3.6->apache-airflow) (1.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from pydantic>=1.10.0->apache-airflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /opt/anaconda3/lib/python3.8/site-packages (from pydantic>=1.10.0->apache-airflow) (2.10.1)
# Requirement already satisfied: docutils in /opt/anaconda3/lib/python3.8/site-packages (from python-daemon>=3.0.0->apache-airflow) (0.20.1)
# Requirement already satisfied: setuptools>=62.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from python-daemon>=3.0.0->apache-airflow) (68.2.2)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.9.1->connexion[flask]<3.0,>=2.10.0->apache-airflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.9.1->connexion[flask]<3.0,>=2.10.0->apache-airflow) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.9.1->connexion[flask]<3.0,>=2.10.0->apache-airflow) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from sqlalchemy<2.0,>=1.4.28->apache-airflow) (3.0.1)
# Requirement already satisfied: sqlparse>=0.4.2 in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow-providers-common-sql->apache-airflow) (0.4.4)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow-providers-http->apache-airflow) (3.8.6)
# Requirement already satisfied: requests-toolbelt in /opt/anaconda3/lib/python3.8/site-packages (from apache-airflow-providers-http->apache-airflow) (1.0.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.4.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from httpx->apache-airflow) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from httpx->apache-airflow) (1.5.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.8/site-packages (from httpx->apache-airflow) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.8/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/anaconda3/lib/python3.8/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (4.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-exporter-otlp->apache-airflow) (1.20.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-exporter-otlp->apache-airflow) (1.20.0)
# Requirement already satisfied: opentelemetry-proto==1.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp->apache-airflow) (1.20.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp->apache-airflow) (1.61.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp->apache-airflow) (1.20.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp->apache-airflow) (1.59.2)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp->apache-airflow) (1.10.0)
# Requirement already satisfied: opentelemetry-sdk~=1.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp->apache-airflow) (1.20.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-proto==1.20.0->opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp->apache-airflow) (4.24.4)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.41b0 in /opt/anaconda3/lib/python3.8/site-packages (from opentelemetry-sdk~=1.20.0->opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp->apache-airflow) (0.41b0)
# Building wheels for collected packages: google-re2
#   Building wheel for google-re2 (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-install-hui5rl8j/google-re2_1586a15dc1c440f0b8de502cffd99262/setup.py'"'"'; __file__='"'"'/private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-install-hui5rl8j/google-re2_1586a15dc1c440f0b8de502cffd99262/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-wheel-vvmjg2ar
#        cwd: /private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-install-hui5rl8j/google-re2_1586a15dc1c440f0b8de502cffd99262/
#   Complete output (15 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-cpython-38
#   copying re2.py -> build/lib.macosx-10.9-x86_64-cpython-38
#   running build_ext
#   building '_re2' extension
#   creating build/temp.macosx-10.9-x86_64-cpython-38
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include/python3.8 -c _re2.cc -o build/temp.macosx-10.9-x86_64-cpython-38/_re2.o -fvisibility=hidden
#   _re2.cc:11:10: fatal error: 'pybind11/pybind11.h' file not found
#   #include <pybind11/pybind11.h>
#            ^~~~~~~~~~~~~~~~~~~~~
#   1 error generated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for google-re2
#   Running setup.py clean for google-re2
# Failed to build google-re2
# Installing collected packages: google-re2, flask-session, flask-caching, flask-appbuilder, dill, croniter, cron-descriptor, configupdater, colorlog, cattrs, blinker, argcomplete, apache-airflow-providers-sqlite, apache-airflow-providers-imap, apache-airflow-providers-http, apache-airflow-providers-ftp, alembic, apache-airflow
#     Running setup.py install for google-re2 ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-install-hui5rl8j/google-re2_1586a15dc1c440f0b8de502cffd99262/setup.py'"'"'; __file__='"'"'/private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-install-hui5rl8j/google-re2_1586a15dc1c440f0b8de502cffd99262/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-record-bh7npv0u/install-record.txt --single-version-externally-managed --compile --install-headers /opt/anaconda3/include/python3.8/google-re2
#          cwd: /private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-install-hui5rl8j/google-re2_1586a15dc1c440f0b8de502cffd99262/
#     Complete output (28 lines):
#     running install
#     /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` directly.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#             ********************************************************************************
#
#     !!
#       self.initialize_options()
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-x86_64-cpython-38
#     copying re2.py -> build/lib.macosx-10.9-x86_64-cpython-38
#     running build_ext
#     building '_re2' extension
#     creating build/temp.macosx-10.9-x86_64-cpython-38
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include/python3.8 -c _re2.cc -o build/temp.macosx-10.9-x86_64-cpython-38/_re2.o -fvisibility=hidden
#     _re2.cc:11:10: fatal error: 'pybind11/pybind11.h' file not found
#     #include <pybind11/pybind11.h>
#              ^~~~~~~~~~~~~~~~~~~~~
#     1 error generated.
#     error: command '/usr/bin/gcc' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-install-hui5rl8j/google-re2_1586a15dc1c440f0b8de502cffd99262/setup.py'"'"'; __file__='"'"'/private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-install-hui5rl8j/google-re2_1586a15dc1c440f0b8de502cffd99262/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/zx/h1j27ppn3kq1md12x3h7xf3r0000gn/T/pip-record-bh7npv0u/install-record.txt --single-version-externally-managed --compile --install-headers /opt/anaconda3/include/python3.8/google-re2 Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
from datetime import datetime
from airflow import DAG
from airflow.contrib.sensors.file_sensor import FileSensor
from airflow.operators.python_operator import PythonOperator
from airflow.operators.bash_operator import BashOperator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-22737a3b81c2> in <module>
#       1 import re
#       2 from datetime import datetime
# ----> 3 from airflow import DAG
#       4 from airflow.contrib.sensors.file_sensor import FileSensor
#       5 from airflow.operators.python_operator import PythonOperator
#
# ImportError: cannot import name 'DAG' from 'airflow' (unknown location)
