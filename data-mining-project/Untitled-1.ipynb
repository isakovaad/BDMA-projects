# %%
{
  "_id": "info-h-415",
  "name": "advanced databases",
  "price": 699.99,
  "features": { "tool1": "MongoDB", "tool2": "CouchDB", "tool3": "PostgreSQL" },
  "reviews": [ { "user": "student1", "rating": 4.5, "comment": "MongoDB is better" } ],
  "specs": [ "we got this", "hope to get a high score", "we are tired, but happy" ],
}




{
  "_id": 1,
  "title": "The best professor",
  "author": {
    "name": "Esteban",
    "email": "estebanzimanyi@gmail.com"
  },
  "content": "A document store is a type of NoSQL database...",
  "tags": ["NoSQL", "Document Store", "MongoDB"],
}





{
     "_id": 1,
     "first_name": "Tom",
     "email": "tom@example.com",
     "cell": "765-555-5555",
     "likes": [
        "fashion",
        "spas",
        "shopping"
     ],
     "businesses": [
        {
           "name": "Entertainment 1080",
           "partner": "Jean",
           "status": "Bankrupt",
           "date_founded": {
              "$date": "2012-05-19T04:00:00Z"
           }
        },
        {
           "name": "Swag for Tweens",
           "date_founded": {
              "$date": "2012-11-01T04:00:00Z"
           }
        }
     ]
  }








{"_id": {"$oid": "59435317a7986c085b592f10"}, 
 "coordinates": null, 
 "in_reply_to_status_id": null, 
 "text": "hungryyyy \ue043\ue120\ue33b", 
 "favorited": false, 
 "entities": {"hashtags": [], "user_mentions": [], "urls": []}, 
 "retweet_count": 0, 
 "in_reply_to_screen_name": null, 
 "source": "<a href=\"http://twitter.com/#!/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>"
 "place": null,
 "id_str": "134452349002448896", 
 "retweeted": false, 
 "created_at": "Thu Nov 10 02:08:32 +0000 2011", 
 "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, 
 "geo": null, "in_reply_to_user_id_str": null, 
 "user": {"listed_count": 0, "profile_background_tile": true,"profile_sidebar_fill_color": "e0dcd9",
          "location": "hiding with tupac ;)","contributors_enabled": false, "statuses_count": 2879, "notifications": null, 
           "profile_sidebar_border_color": "ebe9e6", 
           "description": "eff a bio , follow mee & see what im aboutttt \ue011\ue32d\ue056 btw : @YoungSavage215 is followinggg meee (;", 
           "default_profile_image": false,"show_all_inline_media": false, "lang": "en", 
           "profile_image_url_https": "https://si0.twimg.com/profile_images/1619798000/image_normal.jpg", 
           "profile_use_background_image": true, "id_str": "200380724", "time_zone": "Central Time (US & Canada)", 
           "created_at": "Sat Oct 09 04:12:06 +0000 2010", "profile_text_color": "333333", "follow_request_sent": null, 
           "following": null, "profile_background_image_url": "http://a3.twimg.com/profile_background_images/355484256/tpain.jpg", 
           "favourites_count": 5, "followers_count": 154, "protected": false, 
           "profile_image_url": "http://a2.twimg.com/profile_images/1619798000/image_normal.jpg", 
           "default_profile": false, "geo_enabled": false, "profile_link_color": "0084B4", "screen_name": "toodles_TIFFANY", 
           "name": "\ue328\ue32e Tiffanyyy \ue32e\ue328", "verified": false, "url": "http://www.ITSMYWORLDBITCH.org", 
           "id": 200380724, "is_translator": false, 
           "profile_background_image_url_https": "https://si0.twimg.com/profile_background_images/355484256/tpain.jpg", 
           "utc_offset": -21600, "friends_count": 146, 
           "profile_background_color": "C0DEED"}
